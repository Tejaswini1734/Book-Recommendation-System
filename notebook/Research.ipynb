# %%
print("Internship")

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\Admin\\OneDrive\\Documents\\ML-Project\\Book-Recommendation-System\\.venv\\Scripts\\python.exe'

# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('data/BX-Books.csv', sep=","
